# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
#carregando o arquivo
file = pd.read_csv('bigml_5bf3066600a1e56a970016f7.csv')

# %%
file.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# ...

# %%
file.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
file.shape
# Out:
# (3333, 20)

# %%
d = {'No' : False , 'Yes' : True}
file['International plan'] = file['International plan'].map(d)
file['Voice mail plan'] = file['Voice mail plan'].map(d)

# %%
file.head(10)
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
# 5    AL             118        510                True            False
# 6    MA             121        510               False             True
# 7    MO             147        415                True            False
# 8    LA             117        408               False            False
# 9    WV             141        415                True             True
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# ...

# %%
file.describe()
# Out:
#        Account length    Area code  Number vmail messages  Total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %%
file['TOTAL MINUTES'] = file['Total day minutes'] + file['Total eve minutes'] + file['Total night minutes'] + file['Total intl minutes']
file['TOTAL CALLS'] = file['Total day calls'] + file['Total eve calls'] + file['Total night calls'] + file['Total intl calls']
file['TOTAL CHARGES'] = file['Total day charge'] + file['Total eve charge'] + file['Total night charge'] + file['Total intl charge']
file.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  ...  Total night calls  \
# 0             45.07              197.4  ...                 91
# ...

# %%
file.drop(['Total day minutes', 'Total eve minutes', 'Total night minutes', 'Total intl minutes', 'Total day calls', 'Total eve calls', 'Total night calls', 'Total intl calls', 'Total day charge', 'Total eve charge', 'Total night charge', 'Total intl charge'], axis=1, inplace=True)
file.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Customer service calls  Churn  TOTAL MINUTES  \
# 0                     25                       1  False          717.2
# 1                     26                       1  False          625.2
# 2                      0                       0  False          539.4
# 3                      0                       2  False          564.8
# 4                      0                       3  False          512.0
#
#    TOTAL CALLS  TOTAL CHARGES
# 0          303          75.56
# 1          332          59.24
# ...

# %%
file.to_csv('baseProcessadaFinal.csv')
