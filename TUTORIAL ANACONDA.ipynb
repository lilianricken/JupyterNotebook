# %% [markdown]
# <h1>Tutorial de Anaconda</h1>
#     <h3>Preparação e análise de dados</h3>
#         <br>Semana 2 e 3</br>
#         <br>Tutorial apresentado no blog de <b>Paulo Henrique Vasconcellos</b></br>

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
#carregando o arquivo
videoGame = pd.read_csv('vgsales.csv')

# %%
#Exibir as x primeiras lindas do dataset objeto.head(X)
videoGame.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# ...

# %%
#apresentar um resumo estatístico do dataset
videoGame.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %%
#tipos de dados das colunas
videoGame.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
#tamanho da tabela
videoGame.shape
# Out:
# (16598, 11)

# %%
#Renomeando colunas
videoGame.columns = ['Ranking', 'Nome', 'Plataforma', 'Ano',
                      'Gênero', 'Editora', 'Vendas América do Norte', 'Vendas EUA',
                      'Vendas Japão', 'Outras vendas', 'Vendas Global']

# %%
videoGame.head(10)
# Out:
#    Ranking                       Nome Plataforma     Ano        Gênero  \
# 0        1                 Wii Sports        Wii  2006.0        Sports
# 1        2          Super Mario Bros.        NES  1985.0      Platform
# 2        3             Mario Kart Wii        Wii  2008.0        Racing
# 3        4          Wii Sports Resort        Wii  2009.0        Sports
# 4        5   Pokemon Red/Pokemon Blue         GB  1996.0  Role-Playing
# 5        6                     Tetris         GB  1989.0        Puzzle
# 6        7      New Super Mario Bros.         DS  2006.0      Platform
# 7        8                   Wii Play        Wii  2006.0          Misc
# 8        9  New Super Mario Bros. Wii        Wii  2009.0      Platform
# 9       10                  Duck Hunt        NES  1984.0       Shooter
#
#     Editora  Vendas América do Norte  Vendas EUA  Vendas Japão  Outras vendas  \
# 0  Nintendo                    41.49       29.02          3.77           8.46
# ...

# %%
videoGame [videoGame['Ano'].isnull()].head()
# Out:
#      Ranking                        Nome Plataforma  Ano    Gênero  \
# 179      180             Madden NFL 2004        PS2  NaN    Sports
# 377      378            FIFA Soccer 2004        PS2  NaN    Sports
# 431      432  LEGO Batman: The Videogame        Wii  NaN    Action
# 470      471  wwe Smackdown vs. Raw 2006        PS2  NaN  Fighting
# 607      608              Space Invaders       2600  NaN   Shooter
#
#                                     Editora  Vendas América do Norte  \
# 179                         Electronic Arts                     4.26
# 377                         Electronic Arts                     0.59
# 431  Warner Bros. Interactive Entertainment                     1.86
# 470                                     NaN                     1.57
# 607                                   Atari                     2.36
#
#      Vendas EUA  Vendas Japão  Outras vendas  Vendas Global
# 179        0.26          0.01           0.71           5.23
# ...

# %%
videoGame['Plataforma'].value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# WS         6
# SCD        6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Plataforma, dtype: int64

# %%
titulos_lancados = videoGame['Plataforma'].value_counts()
titulos_lancados.plot()
videoGame['Plataforma'].value_counts().plot()

# %%
videoGame['Plataforma'].value_counts().head(10).plot(kind='bar', figsize=(11,5), grid=False, rot=0, color='green')

plt.title('Os 10 Videogames com mais titulos lançados')
plt.xlabel('Videogame')
plt.ylabel('Quantidade de jogos lançados')
plt.show()

# %%
top10Vendidos = videoGame[['Nome', 'Vendas Global']].head(10).set_index('Nome').sort_values('Vendas Global', ascending = True)
top10Vendidos.plot(kind='barh', figsize=(11,7), grid = False, color = 'darkred', legend=False)

plt.title('Os 10 jogos mais vendidos no mundo')
plt.xlabel('Total de vendas (em milhões de dolares)')
plt.show()

# %%
crosstab_vg = pd.crosstab(videoGame['Plataforma'], videoGame['Gênero'])
crosstab_vg.head()
# Out:
# Gênero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# 2600            61          2         2     5         9      11       6
# 3DO              0          1         0     0         0       1       0
# 3DS            182         37        14    53        28      20      11
# DC               3         11        12     0         2       0       6
# DS             343        240        36   393        92     238      67
#
# Gênero      Role-Playing  Shooter  Simulation  Sports  Strategy
# Plataforma
# 2600                   0       24           1      12         0
# 3DO                    0        0           1       0         0
# 3DS                   86        7          30      26        15
# DC                     4        3           1      10         0
# DS                   200       42         285     148        79

# %%
crosstab_vg['Total'] = crosstab_vg.sum(axis=1)
crosstab_vg.head()
# Out:
# Gênero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# 2600            61          2         2     5         9      11       6
# 3DO              0          1         0     0         0       1       0
# 3DS            182         37        14    53        28      20      11
# DC               3         11        12     0         2       0       6
# DS             343        240        36   393        92     238      67
#
# Gênero      Role-Playing  Shooter  Simulation  Sports  Strategy  Total
# Plataforma
# 2600                   0       24           1      12         0    133
# 3DO                    0        0           1       0         0      3
# 3DS                   86        7          30      26        15    509
# DC                     4        3           1      10         0     52
# DS                   200       42         285     148        79   2163

# %%
top10Plataforms = crosstab_vg[crosstab_vg['Total']>1000].sort_values('Total', ascending = False)
top10Final = top10Plataforms.append(pd.DataFrame(top10Plataforms.sum(), columns=['total']).T, ignore_index=False)

sns.set(font_scale=1)
plt.figure(figsize=(18,9))
sns.heatmap(top10Final, annot=True, vmax=top10Final.loc[:'PS', :'Strategy'].values.max(), vmin=top10Final.loc[:, :'Strategy'].values.min(), fmt='d')

plt.title('Quantidade de Títulos por Gênero e Console')
plt.xlabel('Gênero')
plt.ylabel('Console')
plt.show()
